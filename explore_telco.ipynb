# %% [markdown]
# Do your work in a notebook named explore_telco. In addition, you should create a file named explore.py that contains the following functions for exploring your variables (features & target).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
import sklearn.preprocessing

import explore
import acquire
import env

# %% [markdown]
# 1. Write a function named plot_variable_pairs that accepts a dataframe as input and plots all of the pairwise relationships along with the regression line for each pair.

# %%
#def plot_variable_pairs():
    #'''accepts a dataframe as input
    #split into train, validate, and test
    #plots all of the pairwise relationships along with the regression line for each pair.'''
    # Take in the dataframe
    #df = acquire.acquire_all_telco()
    # split the data
    #train, test = train_test_split(df, test_size=.2, random_state=1234)
    #train, validate = train_test_split(train, test_size=.3, random_state=1234)
    # plot pairwise relationships using train data
    #sns.pairplot(train, hue="churn")
    #return train

# %%
train = explore.plot_variable_pairs()
train.head()
# Out:
#       contract_type_id customer_id  gender  senior_citizen partner dependents  \
# 4492                 2  4323-ELYYB    Male               0     Yes        Yes
# 843                  1  2235-DWLJU  Female               1      No         No
# 5441                 3  0556-FJEGU    Male               0      No         No
# 448                  1  1216-JWVUX    Male               0     Yes        Yes
# 1720                 1  4396-KLSEH    Male               0      No         No
#
#       tenure phone_service    multiple_lines  internet_service_type_id  ...  \
# 4492      13           Yes                No                         3  ...
# 843        6            No  No phone service                         1  ...
# 5441      58           Yes                No                         1  ...
# 448       25           Yes                No                         2  ...
# 1720       4           Yes                No                         3  ...
#
# ...

# %%
#df = acquire.acquire_all_telco()
#df.head()

# %%
#train, test = train_test_split(df, test_size=.2, random_state=1234)
#train, validate = train_test_split(train, test_size=.3, random_state=1234)
#train.head()

# %%
#sns.pairplot(train, hue="churn")

# %% [markdown]
# 2. Write a function named months_to_years that accepts your telco churn dataframe and returns a dataframe with a new feature tenure_years, in complete years as a customer.

# %%
#def months_to_years():
    #'''accepts your telco churn dataframe 
    #splits data into train, validate, and test
    #returns a dataframe with a new feature tenure_years, in complete years as a customer.'''
    # accept data
    #df = acquire.acquire_all_telco()
    # split data
    #train, test = train_test_split(df, test_size=.2, random_state=1234)
    #train, validate = train_test_split(train, test_size=.3, random_state=1234)
    # make tenure_year
    #train['tenure_years'] = round(df.tenure / 12, 2)
    # rename tenure to tenure_month
    #train = train.rename(columns={'tenure': 'tenure_month'})
    #return train

# %%
train = explore.months_to_years()
train.head()
# Out:
#       contract_type_id customer_id  gender  senior_citizen partner dependents  \
# 4492                 2  4323-ELYYB    Male               0     Yes        Yes
# 843                  1  2235-DWLJU  Female               1      No         No
# 5441                 3  0556-FJEGU    Male               0      No         No
# 448                  1  1216-JWVUX    Male               0     Yes        Yes
# 1720                 1  4396-KLSEH    Male               0      No         No
#
#       tenure_month phone_service    multiple_lines  internet_service_type_id  \
# 4492            13           Yes                No                         3
# 843              6            No  No phone service                         1
# 5441            58           Yes                No                         1
# 448             25           Yes                No                         2
# 1720             4           Yes                No                         3
#
# ...

# %%
#df = acquire.acquire_all_telco()
#df.head()

# %%
#train, test = train_test_split(df, test_size=.2, random_state=1234)
#train, validate = train_test_split(train, test_size=.3, random_state=1234)
#train.head()

# %%
#train['tenure_years'] = round(df.tenure_monhts / 12, 2)
#train.head()

# %%
#train = train.rename(columns={'tenure': 'tenure_month'})
#train.head()

# %% [markdown]
# 3. Write a function named plot_categorical_and_continuous_vars that accepts your dataframe and the name of the columns that hold the continuous and categorical features and outputs 3 different plots for visualizing a categorical variable and a continuous variable.

# %%
#def plot_categorical_and_continuous_vars():
    #'''accepts your dataframe
    #accepts the name of the columns that hold the continuous and categorical features
    #outputs 3 different plots for visualizing a categorical variable and a continuous variable.
    #'''
    # get it
    #df = acquire.acquire_all_telco()
    # split it
    #train, test = train_test_split(df, test_size=.2, random_state=1234)
    #train, validate = train_test_split(train, test_size=.3, random_state=1234)
    # make the visuals
    #plt.subplots(3, 1, figsize=(13,25), sharey=True)
    #sns.set(style="darkgrid")
        # Monthly Charges and Churn
    #plt.subplot(3,1,1)
    #sns.barplot(x='churn',y='monthly_charges',data=train)
    #plt.title('Distribution of Monthly Charges')
        # Tenure and Churn
    #plt.subplot(3,1,2)
    #sns.boxplot(x='churn',y='tenure',data=train,palette='rainbow')
    #plt.title('Distribution of Tenure')
        # Total Charges and Churn
    #plt.subplot(3,1,3)
    #sns.stripplot(x="churn", y="total_charges", data=train, palette='rainbow')
    #plt.title('Distribution of Total Charges')
    #return train

# %%
train = explore.plot_categorical_and_continuous_vars()
train.head()
# Out:
#       contract_type_id customer_id  gender  senior_citizen partner dependents  \
# 4492                 2  4323-ELYYB    Male               0     Yes        Yes
# 843                  1  2235-DWLJU  Female               1      No         No
# 5441                 3  0556-FJEGU    Male               0      No         No
# 448                  1  1216-JWVUX    Male               0     Yes        Yes
# 1720                 1  4396-KLSEH    Male               0      No         No
#
#       tenure phone_service    multiple_lines  internet_service_type_id  ...  \
# 4492      13           Yes                No                         3  ...
# 843        6            No  No phone service                         1  ...
# 5441      58           Yes                No                         1  ...
# 448       25           Yes                No                         2  ...
# 1720       4           Yes                No                         3  ...
#
# ...

# %%
# accepts your dataframe and names of the columns
#df = acquire.acquire_all_telco()
#df.head()

# %%
#train, test = train_test_split(df, test_size=.2, random_state=1234)
#train, validate = train_test_split(train, test_size=.3, random_state=1234)
#train.head()

# %%
# This is just a way to make it look better in my opinion

#plt.subplots(3, 1, figsize=(13,25), sharey=True)
#sns.set(style="darkgrid")

# Monthly Charges and Churn
#plt.subplot(3,1,1)
#sns.barplot(x='churn',y='monthly_charges',data=train)
#plt.title('Distribution of Monthly Charges')

# Tenure and Churn
#plt.subplot(3,1,2)
#sns.boxplot(x='churn',y='tenure',data=train,palette='rainbow')
#plt.title('Distribution of Tenure')

# Total Charges and Churn
#plt.subplot(3,1,3)
#sns.stripplot(x="total_charges", y="churn", data=train, palette='rainbow')
#plt.title('Distribution of Total Charges')

# %% [markdown]
# 4. Save the functions you have written to create visualizations in a file named explore.py. Rewrite your notebook code so that you are using the functions imported from this file.

# %% [markdown]
# All done

# %% [markdown]
# 5. Explore your dataset with any other visualizations you think will be helpful.

# %%
train.head()
# Out:
#       contract_type_id customer_id  gender  senior_citizen partner dependents  \
# 4492                 2  4323-ELYYB    Male               0     Yes        Yes
# 843                  1  2235-DWLJU  Female               1      No         No
# 5441                 3  0556-FJEGU    Male               0      No         No
# 448                  1  1216-JWVUX    Male               0     Yes        Yes
# 1720                 1  4396-KLSEH    Male               0      No         No
#
#       tenure phone_service    multiple_lines  internet_service_type_id  ...  \
# 4492      13           Yes                No                         3  ...
# 843        6            No  No phone service                         1  ...
# 5441      58           Yes                No                         1  ...
# 448       25           Yes                No                         2  ...
# 1720       4           Yes                No                         3  ...
#
# ...

# %%
train['churn'] = (train['churn'] == True ).astype(int)

# %%
sns.boxplot(x="total_charges",y="churn",hue="contract_type",data=train, palette="rainbow")
# Out:
# <AxesSubplot:xlabel='total_charges', ylabel='churn'>

# %% [markdown]
# 6. In a seperate notebook, use the functions you have developed in this exercise with the mall customers dataset.
